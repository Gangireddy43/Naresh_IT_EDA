# %% [markdown]
# Reading the csv file

# %%
import pandas as pd              #dataframe operations
import numpy as np               # math operation
import matplotlib.pyplot as plt  # diagrams / plots 
import seaborn as sns            # diagrams / plots

# %%
# data set name : visadataset
# read csv file : comma separated value 
# extation : csv
# you can read the using pandas packages 

#raed excal file
#extation .xlsx

# %%
# path 
# file location + filename +extation
path = r'C:\Users\REDDY\DATA SCIENCE\python datafiles\Visadataset - Visadataset.csv'

# %%
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r'C:\Users\REDDY\DATA SCIENCE\python datafiles\bank - bank.csv'

# %%
pd.read_csv(path)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# Creat dataframes using list

# %%
name = ['ramesh','suresh','babu']
age = [23,34,32]
name,age
# Out:
# (['ramesh', 'suresh', 'babu'], [23, 34, 32])

# %% [markdown]
# $creat$data$frame$

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
data = pd.DataFrame(zip(name,age))
data
# Out:
#         0   1
# 0  ramesh  23
# 1  suresh  34
# 2    babu  32

# %%
# provide colums 
data = zip(name,age)
cols = ['name','age']
pd.DataFrame(data,columns=cols)
# Out:
#      name  age
# 0  ramesh   23
# 1  suresh   34
# 2    babu   32

# %% [markdown]
# $ provide index $

# %%
# provide index
data = zip(name,age)
cols = ['name','age']
ind = ['A','B','c']
df=pd.DataFrame(data,columns=cols,index=ind)
df
# Out:
#      name  age
# A  ramesh   23
# B  suresh   34
# c    babu   32

# %% [markdown]
# $ add new column $

# %%
name = ['ramesh','suresh','babu']
age = [23,34,32]

# %% [markdown]
# - if tou want to add the a new column
# - df ['new column']
# - you need to have a list which is some elements
# - that elements need to equal to number of rows
# - city_name =['hyd','bnglr','chennai']
# - df['city']=city_name

# %%
city_name =['hyd','bnglr','chennai']
df['city']=city_name
df
# Out:
#      name  age     city
# A  ramesh   23      hyd
# B  suresh   34    bnglr
# c    babu   32  chennai

# %% [markdown]
# $update the exsisting column$
# - if you want to creat coumn or update the old column
# - both are same way

# %%
df['name']= ['swamy','Reddy','sathwik']
df
# Out:
#       name  age     city
# A    swamy   23      hyd
# B    Reddy   34    bnglr
# c  sathwik   32  chennai

# %% [markdown]
# $ drop the column $
# - in order to drop the column
# - we need to use drop method
# - it takes 3 parameters
#    - drop column or row
#     - mention the column name
#     - axis
#         - axiz=1 referance as column
#         - axis=0 referanceas row
#     - yo want to creat a new dataframe or
#     - you want overwrite the existing dataframe
#        - inplace=true

# %%
df.drop('city',
        axis=1,
        inplace=True)     # overwrite the same 
df
# Out:
#       name  age
# A    swamy   23
# B    Reddy   34
# c  sathwik   32

# %%
df.drop('name',
       axis=1)
# Out:
#    age
# A   23
# B   34
# c   32

# %%
name = ['ramesh','suresh','babu']
age = [23,34,32]
name,age
data = pd.DataFrame(zip(name,age))
data
data = zip(name,age)
cols = ['name','age']
pd.DataFrame(data,columns=cols)
data = zip(name,age)
cols = ['name','age']
ind = ['A','B','c']
df=pd.DataFrame(data,columns=cols,index=ind)
df     
name = ['ramesh','suresh','babu']
age = [23,34,32]
city_name =['hyd','bnglr','chennai']
df['city']=city_name
df
df['name']= ['swamy','Reddy','sathwik']
df
df.drop('city',
        axis=1,
        inplace=True)     # overwrite the same 
df
df.drop('name',
       axis=1,
       inplace=True)
df
# Out:
#    age
# A   23
# B   34
# c   32

# %% [markdown]
# $ save the data frame $

# %%
df.to_csv("Gangi.csv",index=False)

# %%
#read gangi csv
pd.read_csv("Gangi.csv")
# Out:
#    age
# 0   23
# 1   34
# 2   32

# %%
# to avoid the above problem
# give index=False

# %% [markdown]
# $Creat dataframe using dictionary$

# %%
d1={"name":['ramesh','suresh','babu'],
   "age":[23,34,32]}
pd.DataFrame(d1)
# Out:
#      name  age
# 0  ramesh   23
# 1  suresh   34
# 2    babu   32
